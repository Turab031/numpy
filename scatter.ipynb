# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

people = ["a","b","c","d","e","f","g","h","i","J"]
age = [22,25,38,40,4,50,55,65,70,75]   # now 10 values
bp = [110,115,120,122,125,130,135,123,150,155]

plt.scatter(age, bp)
plt.title("Age vs BP")
plt.xlabel("Age")
plt.ylabel("BP")
plt.show()
